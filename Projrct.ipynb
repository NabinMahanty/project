# %%
import pandas as pd

# %%
data = pd.read_csv('Indian automoble buying behavour study 1.0.csv')
data.head(5)
# Out:
#    Age Profession Marrital Status      Education  No of Dependents  \
# 0   27   Salaried          Single  Post Graduate                 0
# 1   35   Salaried         Married  Post Graduate                 2
# 2   45   Business         Married       Graduate                 4
# 3   41   Business         Married  Post Graduate                 3
# 4   31   Salaried         Married  Post Graduate                 2
#
#   Personal loan House Loan Wife Working   Salary  Wife Salary  Total Salary  \
# 0           Yes         No           No   800000            0        800000
# 1           Yes        Yes          Yes  1400000       600000       2000000
# 2           Yes        Yes           No  1800000            0       1800000
# 3            No         No          Yes  1600000       600000       2200000
# 4           Yes         No          Yes  1800000       800000       2600000
#
#      Make    Price
# 0     i20   800000
# 1    Ciaz  1000000
# 2  Duster  1200000
# 3    City  1200000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               99 non-null     int64
#  1   Profession        99 non-null     object
#  2   Marrital Status   99 non-null     object
#  3   Education         99 non-null     object
#  4   No of Dependents  99 non-null     int64
#  5   Personal loan     99 non-null     object
#  6   House Loan        99 non-null     object
#  7   Wife Working      99 non-null     object
#  8   Salary            99 non-null     int64
#  9   Wife Salary       99 non-null     int64
#  10  Total Salary      99 non-null     int64
#  11  Make              99 non-null     object
#  12  Price             99 non-null     int64
# dtypes: int64(6), object(7)
# memory usage: 10.2+ KB

# %%
data.describe()
# Out:
#              Age  No of Dependents        Salary   Wife Salary  Total Salary  \
# count  99.000000         99.000000  9.900000e+01  9.900000e+01  9.900000e+01
# mean   36.313131          2.181818  1.736364e+06  5.343434e+05  2.270707e+06
# std     6.246054          1.335265  6.736217e+05  6.054450e+05  1.050777e+06
# min    26.000000          0.000000  2.000000e+05  0.000000e+00  2.000000e+05
# 25%    31.000000          2.000000  1.300000e+06  0.000000e+00  1.550000e+06
# 50%    36.000000          2.000000  1.600000e+06  5.000000e+05  2.100000e+06
# 75%    41.000000          3.000000  2.200000e+06  9.000000e+05  2.700000e+06
# max    51.000000          4.000000  3.800000e+06  2.100000e+06  5.200000e+06
#
#               Price
# count  9.900000e+01
# mean   1.194040e+06
# std    4.376955e+05
# min    1.100000e+05
# 25%    8.000000e+05
# 50%    1.200000e+06
# 75%    1.500000e+06
# max    3.000000e+06

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")

# %% [markdown]
# # 1. Age Distribution

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], kde=True, bins=10, color='skyblue')
plt.title('Age Distribution of Automobile Buyers in India')
plt.xlabel('Age')
plt.ylabel('Number of Buyers')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Profession Breakdown

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Profession', palette='Set2',hue = "Marrital Status")
plt.title('Profession Breakdown (Salaried vs Business)')
plt.xlabel('Profession')
plt.ylabel('Count of Buyers')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 3. Marital Status Breakdown

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Marrital Status', palette='Set1')
plt.title('Marital Status of Automobile Buyers')
# Out:
# C:\Users\nabin\AppData\Local\Temp\ipykernel_11712\3447931749.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Marrital Status', palette='Set1')
# Text(0.5, 1.0, 'Marital Status of Automobile Buyers')

# %% [markdown]
# # 4. Most Popular Car Makes

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Make', order=data['Make'].value_counts().index, palette='Set3')
plt.title('Most Popular Car Makes')
plt.xlabel('Car Make')
plt.ylabel('Count of Buyers')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\nabin\AppData\Local\Temp\ipykernel_11712\1131196937.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=data, x='Make', order=data['Make'].value_counts().index, palette='Set3')

# %% [markdown]
# # 5. Salary vs Car Price Analysis

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Salary', y='Price', hue='Profession', palette='Set2', s=100)
plt.title('Salary vs Car Price')
plt.xlabel('Salary (INR)')
plt.ylabel('Car Price (INR)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6. Loan Influence on Car Purchase (Personal Loan and House Loan)

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.boxplot(data=data, x='Personal loan', y='Price', palette='Set1',hue='Profession')
plt.title('Car Price Distribution by Personal Loan Status')
plt.xlabel('Personal Loan')
plt.ylabel('Car Price (INR)')

plt.subplot(1, 2, 2)
sns.boxplot(data=data, x='House Loan', y='Price', palette='Set1',hue='Profession')
plt.title('Car Price Distribution by House Loan Status')
plt.xlabel('House Loan')
plt.ylabel('Car Price (INR)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7. Car Make Preference by Profession

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=data, x='Make', hue='Profession', palette='Set3', order=data['Make'].value_counts().index)
plt.title('Car Make Preference by Profession')
plt.xlabel('Car Make')
plt.ylabel('Count of Buyers')
plt.xticks(rotation=45)
plt.tight_layout()

# %% [markdown]
# # 8. Total Household Income vs Car Price

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Total Salary', y='Price', hue='Marrital Status', palette='Set2', s=100)
plt.title('Total Household Income vs Car Price')
plt.xlabel('Total Household Income (INR)')
plt.ylabel('Car Price (INR)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 9. Dependents and Car Price

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=data, x='No of Dependents', y='Price', palette='Set1',hue = "Profession")
plt.title('Dependents and Car Price')
plt.xlabel('Number of Dependents')
plt.ylabel('Car Price (INR)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10. Car Make vs Loan Status

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.countplot(data=data, x='Make', hue='Personal loan', palette='Set2', order=data['Make'].value_counts().index)
plt.title('Car Make Preference by Personal Loan Status')
plt.xlabel('Car Make')
plt.ylabel('Count of Buyers')
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
sns.countplot(data=data, x='Make', hue='House Loan', palette='Set3', order=data['Make'].value_counts().index)
plt.title('Car Make Preference by House Loan Status')
plt.xlabel('Car Make')
plt.ylabel('Count of Buyers')
plt.xticks(rotation=45)

plt.tight_layout()

# %% [markdown]
# # 11. Age vs Car Price

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='Age', y='Price', hue='Profession', palette='Set1', s=100)
plt.title('Age vs Car Price')
plt.xlabel('Age (Years)')
plt.ylabel('Car Price (INR)')
plt.tight_layout()

# Show the visualizations
plt.show()

# %% [markdown]
# # 12. Household Income vs Loan Status

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.boxplot(data=data, x='Personal loan', y='Total Salary', palette='Set2',hue = "Profession")
plt.title('Household Income vs Personal Loan')
plt.xlabel('Personal Loan')
plt.ylabel('Total Household Income (INR)')
plt.tight_layout()
plt.show()

# %%
plt.subplot(1, 2, 2)
sns.boxplot(data=data, x='House Loan', y='Total Salary', palette='Set3',hue = "Profession")
plt.title('Household Income vs House Loan')
plt.xlabel('House Loan')
plt.ylabel('Total Household Income (INR)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 13. Education Level and Loan Status

# %%
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.countplot(data=data, x='Education', hue='Personal loan', palette='Set2')
plt.title('Education Level vs Personal Loan')
plt.xlabel('Education Level')
plt.ylabel('Count of Buyers')
plt.xticks(rotation=45)

plt.subplot(1, 2, 2)
sns.countplot(data=data, x='Education', hue='House Loan', palette='Set3')
plt.title('Education Level vs House Loan')
plt.xlabel('Education Level')
plt.ylabel('Count of Buyers')
plt.xticks(rotation=45)
plt.tight_layout()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# Select features for clustering
features = ['Age', 'Salary', 'Wife Salary', 'Total Salary', 'Price']
X = data[features]

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Determine optimal number of clusters using silhouette score
silhouette_scores = []
K = range(2, 11)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X_scaled)
    silhouette_scores.append(silhouette_score(X_scaled, kmeans.labels_))

# Plot silhouette scores
plt.plot(K, silhouette_scores, 'bx-')
plt.xlabel('k')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score vs. Number of Clusters')
plt.show()

# Choose the optimal k and fit the model
optimal_k = K[silhouette_scores.index(max(silhouette_scores))]
kmeans = KMeans(n_clusters=optimal_k, random_state=42)
kmeans.fit(X_scaled)

# Add cluster labels to the original dataframe
data['Cluster'] = kmeans.labels_

# Visualize the clusters
plt.figure(figsize=(12, 8))
scatter = plt.scatter(data['Total Salary'], data['Price'], c=data['Cluster'], cmap='viridis')
plt.xlabel('Total Salary')
plt.ylabel('Price')
plt.title('K-Means Clustering: Total Salary vs Price')
plt.colorbar(scatter)
plt.show()
